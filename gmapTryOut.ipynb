# %%
#AIzaSyA5nTPkeIfbHcVYp-XsL45189u6---ry8c
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyA5nTPkeIfbHcVYp-XsL45189u6---ry8c')

# Geocoding an address
geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

# Look up an address with reverse geocoding
reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

# Request directions via public transit
now = datetime.now()
directions_result = gmaps.directions("Sydney Town Hall",
                                     "Parramatta, NSW",
                                     mode="transit",
                                     departure_time=now)
'''
Below is the same example, using client ID and client secret (digital signature) for authentication. This code assumes you have previously loaded the client_id and client_secret variables with appropriate values.

For a guide on how to generate the client_secret (digital signature), see the documentation for the API you're using. For example, see the guide for the Directions API.

gmaps = googlemaps.Client(client_id=client_id, client_secret=client_secret)

# Geocoding and address
geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

# Look up an address with reverse geocoding
reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

# Request directions via public transit
now = datetime.now()
directions_result = gmaps.directions("Sydney Town Hall",
                                     "Parramatta, NSW",
                                     mode="transit",
                                     departure_time=now)'''
# Out:
# '\nBelow is the same example, using client ID and client secret (digital signature) for authentication. This code assumes you have previously loaded the client_id and client_secret variables with appropriate values.\n\nFor a guide on how to generate the client_secret (digital signature), see the documentation for the API you\'re using. For example, see the guide for the Directions API.\n\ngmaps = googlemaps.Client(client_id=client_id, client_secret=client_secret)\n\n# Geocoding and address\ngeocode_result = gmaps.geocode(\'1600 Amphitheatre Parkway, Mountain View, CA\')\n\n# Look up an address with reverse geocoding\nreverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))\n\n# Request directions via public transit\nnow = datetime.now()\ndirections_result = gmaps.directions("Sydney Town Hall",\n                                     "Parramatta, NSW",\n                                     mode="transit",\n                                     departure_time=now)'

# %%
directions_result
# Out:
# [{u'bounds': {u'northeast': {u'lat': -33.8147077, u'lng': 151.208821},
#    u'southwest': {u'lat': -33.8978204, u'lng': 151.0012631}},
#   u'copyrights': u'Map data \xa92018 Google',
#   u'legs': [{u'arrival_time': {u'text': u'7:43pm',
#      u'time_zone': u'Australia/Sydney',
#      u'value': 1526463787},
#     u'departure_time': {u'text': u'7:04pm',
#      u'time_zone': u'Australia/Sydney',
#      u'value': 1526461451},
#     u'distance': {u'text': u'25.2 km', u'value': 25181},
#     u'duration': {u'text': u'39 mins', u'value': 2336},
#     u'end_address': u'Parramatta NSW 2150, Australia',
#     u'end_location': {u'lat': -33.8147077, u'lng': 151.0012631},
#     u'start_address': u'483 George St, Sydney NSW 2000, Australia',
#     u'start_location': {u'lat': -33.8731853, u'lng': 151.2069859},
#     u'steps': [{u'distance': {u'text': u'0.1 km', u'value': 107},
#       u'duration': {u'text': u'2 mins', u'value': 99},
#       u'end_location': {u'lat': -33.8735668, u'lng': 151.2069088},
#       u'html_instructions': u'Walk to Town Hall Station',
#       u'polyline': {u'points': u'lzvmEur{y[Q?UABO@Oh@HBC~@j@'},
#       u'start_location': {u'lat': -33.8731853, u'lng': 151.2069859},
#       u'steps': [{u'distance': {u'text': u'25 m', u'value': 25},
#         u'duration': {u'text': u'1 min', u'value': 18},
#         u'end_location': {u'lat': -33.8730085, u'lng': 151.2070843},
#         u'html_instructions': u'Head <b>north</b> on <b>George St</b> toward <b>Park St</b>',
#         u'polyline': {u'points': u'lzvmEur{y[Q?UABO'},
#         u'start_location': {u'lat': -33.8731853, u'lng': 151.2069859},
#         u'travel_mode': u'WALKING'},
#        {u'distance': {u'text': u'12 m', u'value': 12},
#         u'duration': {u'text': u'1 min', u'value': 18},
#         u'end_location': {u'lat': -33.873017, u'lng': 151.2071572},
#         u'html_instructions': u'Turn <b>right</b> onto <b>Park St</b>',
#         u'maneuver': u'turn-right',
#         u'polyline': {u'points': u'hyvmEgs{y[@O'},
#         u'start_location': {u'lat': -33.8730085, u'lng': 151.2070843},
#         u'travel_mode': u'WALKING'},
#        {u'distance': {u'text': u'30 m', u'value': 30},
#         u'duration': {u'text': u'1 min', u'value': 22},
#         u'end_location': {u'lat': -33.87325, u'lng': 151.20713},
#         u'html_instructions': u'Turn <b>right</b>',
#         u'maneuver': u'turn-right',
#         u'polyline': {u'points': u'jyvmEws{y[h@HBC'},
#         u'start_location': {u'lat': -33.873017, u'lng': 151.2071572},
#         u'travel_mode': u'WALKING'},
#        {u'distance': {u'text': u'40 m', u'value': 40},
#         u'duration': {u'text': u'1 min', u'value': 41},
#         u'end_location': {u'lat': -33.8735668, u'lng': 151.2069088},
#         u'html_instructions': u'Take entrance <span class="location">2. George St</span>',
#         u'polyline': {u'points': u'xzvmEqs{y[~@j@'},
#         u'start_location': {u'lat': -33.87325, u'lng': 151.20713},
#         u'travel_mode': u'WALKING'}],
#       u'travel_mode': u'WALKING'},
#      {u'distance': {u'text': u'24.5 km', u'value': 24498},
#       u'duration': {u'text': u'30 mins', u'value': 1800},
#       u'end_location': {u'lat': -33.8175326, u'lng': 151.0054527},
#       u'html_instructions': u'Train towards Penrith Via Central',
#       u'polyline': {u'points': u'x|vmEer{y[FLbAHnAJ@?@?hDh@D?T?R?JCFAh@Kj@Uf@]b@_@b@e@LQLWLWLULUl@m@t@i@x@c@z@]d@MVI\\I~AQn@CF@hAN@?L@H?H?^Dt@LZDHBB?H@LBZF~BZv@L@@~AXd@JZHd@LLBd@NdA^PFPHb@T~A~@d@\\Sd@`@VpAbALHt@v@~@bAZ^PR^j@zAvBz@nAf@n@r@zAl@x@Xf@Xb@l@x@b@j@\\^Z\\ZZT
#          u'local_icon': u'//maps.gstatic.com/mapfiles/transit/iw2/6/au-sydney-rail.png',
#          u'name': u'Train',
#          u'type': u'HEAVY_RAIL'}},
#        u'num_stops': 5},
#       u'travel_mode': u'TRANSIT'},
#      {u'distance': {u'text': u'0.6 km', u'value': 576},
#       u'duration': {u'text': u'7 mins', u'value': 438},
#       u'end_location': {u'lat': -33.8147077, u'lng': 151.0012631},
#       u'html_instructions': u'Walk to Parramatta NSW 2150, Australia',
#       u'polyline': {u'points': u'p~kmEagtx[z@p@CBKNGJ_AhB]r@Q\\IRQf@CFEVAJCPMB@NE@[@I?GCECGIMJ[NMFMDIBK@UBG@IAC?A?G?YDQBC@CBA@A@A@CBKJKFMDOBG@E?E?IAEXIh@Ip@YpBCNQrA'},
#       u'start_location': {u'lat': -33.8175326, u'lng': 151.0054527},
#       u'steps': [{u'distance': {u'text': u'0.2 km', u'value': 193},
#         u'duration': {u'text': u'2 mins', u'value': 133},
#         u'end_location': {u'lat': -33.8168726, u'lng': 151.0033865},
#         u'html_instructions': u'Head <b>northwest</b> on <b>Liverpool-Parramatta Transitway</b> toward <b>Church St</b>',
#         u'polyline': {u'points': u'p~kmEagtx[z@p@CBKNGJ_AhB]r@Q\\IRQf@CFEVAJCPMB@N'},
#         u'start_location': {u'lat': -33.8175326, u'lng': 151.0054527},
#         u'travel_mode': u'WALKING'},
#        {u'distance': {u'text': u'42 m', u'value': 42},
#         u'duration': {u'text': u'1 min', u'value': 28},
#         u'end_location': {u'lat': -33.816539, u'lng': 151.0034602},
#         u'html_instructions': u'Turn <b>right</b> onto <b>Church St</b>',
#         u'maneuver': u'turn-right',
#         u'polyline': {u'points': u'lzkmEezsx[E@[@I?GCECGI'},
#         u'start_location': {u'lat': -33.8168726, u'lng': 151.0033865},
#         u'travel_mode': u'WALKING'},
#        {u'distance': {u'text': u'0.2 km', u'value': 183},
#         u'duration': {u'text': u'2 mins', u'value': 133},
#         u'end_location': {u'lat': -33.815075, u'lng': 151.0029162},
#         u'html_instructions': u'Turn <b>left</b> to stay on <b>Church St</b>',
#         u'maneuver': u'turn-left',
#         u'polyline': {u'points': u'jxkmEszsx[MJ[NMFMDIBK@UBG@IAC?A?G?YDQBC@CBA@A@A@CBKJKFMDOBG@E?E?IA'},
#         u'start_location': {u'lat': -33.816539, u'lng': 151.0034602},
#         u'travel_mode': u'WALKING'},
#        {u'distance': {u'text': u'0.2 km', u'value': 158},
#         u'duration': {u'text': u'2 mins', u'value': 144},
#         u'end_location': {u'lat': -33.8147077, u'lng': 151.0012631},
#         u'html_instructions': u'Turn <b>left</b> onto <b>Macquarie St</b>',
#         u'maneuver': u'turn-left',
#         u'polyline': {u'points': u'fokmEgwsx[EXIh@Ip@YpBCNQrA'},
